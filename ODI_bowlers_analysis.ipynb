# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Reading an excel file

# %%
df = pd.read_excel("ODI_cricket.xlsx", sheet_name="bowler", engine="openpyxl")

# %% [markdown]
# ### To display the first 10 rows of the dataframe

# %%
display(df.head(10))
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# 5       SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712   9631   393
# 6          GD McGrath (AUS/ICC)  1993-2007  250   248  12970   8391   381
# 7                   B Lee (AUS)  2000-2012  221   217  11185   8877   380
# 8               SL Malinga (SL)  2004-2019  226   220  10936   9760   338
# 9         A Kumble (Asia/INDIA)  1990-2007  271   265  14496  10412   337
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# 4  34.51  4.62  44.7   4   9
# 5  24.50  3.67  39.9  12   5
# 6  22.02  3.88  34.0   9   7
# 7  23.36  4.76  29.4  14   9
# 8  28.87  5.35  32.3  11   8
# 9  30.89  4.30  43.0   8   2

# %% [markdown]
# ### Finding the number of rows and columns in the dataframe

# %%
# number of rows
print("Number of rows = ", df.shape[0])

# number of columns
print("Number of columns = ", df.shape[1])
# Out:
# Number of rows =  77
# Number of columns =  12

# %% [markdown]
# ### Data statistics

# %%
display(df.describe())
# Out:
#               Mat        Inns         Balls          Runs        Wkts  \
# count   77.000000   77.000000     77.000000     77.000000   77.000000
# mean   194.402597  181.194805   8839.402597   6671.714286  233.805195
# std     82.485606   67.958393   3316.055457   2245.839029   84.406603
# min     80.000000   76.000000   4074.000000   2821.000000  151.000000
# 25%    136.000000  128.000000   6182.000000   5058.000000  173.000000
# 50%    170.000000  164.000000   8054.000000   6192.000000  199.000000
# 75%    227.000000  218.000000  10750.000000   8021.000000  272.000000
# max    463.000000  372.000000  18811.000000  13632.000000  534.000000
#
#              Ave       Econ         SR          4          5
# count  77.000000  77.000000  77.000000  77.000000  77.000000
# mean   28.958052   4.596753  37.909091   6.350649   2.870130
# std     4.826768   0.515814   6.060901   3.556929   2.530606
# min    18.680000   3.300000  26.100000   1.000000   0.000000
# 25%    24.970000   4.280000  33.000000   3.000000   1.000000
# 50%    29.290000   4.660000  37.800000   6.000000   2.000000
# 75%    31.900000   4.920000  41.400000   8.000000   4.000000
# max    44.480000   5.830000  52.500000  17.000000  13.000000

# %% [markdown]
# ### Checking data types of each column

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  77 non-null     object
#  1   Span    77 non-null     object
#  2   Mat     77 non-null     int64
#  3   Inns    77 non-null     int64
#  4   Balls   77 non-null     int64
#  5   Runs    77 non-null     int64
#  6   Wkts    77 non-null     int64
#  7   Ave     77 non-null     float64
#  8   Econ    77 non-null     float64
#  9   SR      77 non-null     float64
#  10  4       77 non-null     int64
#  11  5       77 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 7.3+ KB
# None

# %% [markdown]
# #### As there are no null values so there are no missing values present in this dataset.

# %% [markdown]
# ### Printing column names

# %%
print(df.columns)
# Out:
# Index(['Player',   'Span',    'Mat',   'Inns',  'Balls',   'Runs',   'Wkts',
#           'Ave',   'Econ',     'SR',        4,        5],
#       dtype='object')

# %% [markdown]
# ### To rename the column names appropriately

# %%
df = df.rename(columns={'Mat':'Match', 
                        'Inns':'Innings',
                        'Wkts': 'Wicket',
                        'HS': 'Highest_score',
                        'Ave': 'Average',
                        'Econ': 'Economy Rate',
                        'SR': 'Strike_Rate'})

display(df.head())
# Out:
#                          Player       Span  Match  Innings  Balls   Runs  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011    350      341  18811  12326
# 1             Wasim Akram (PAK)  1984-2003    356      351  18186  11812
# 2            Waqar Younis (PAK)  1989-2003    262      258  12698   9919
# 3          WPUJC Vaas (Asia/SL)  1994-2008    322      320  15775  11014
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015    398      372  17670  13632
#
#    Wicket  Average  Economy Rate  Strike_Rate   4   5
# 0     534    23.08          3.93         35.2  15  10
# 1     502    23.52          3.89         36.2  17   6
# 2     416    23.84          4.68         30.5  14  13
# 3     400    27.53          4.18         39.4   9   4
# 4     395    34.51          4.62         44.7   4   9

# %% [markdown]
# ###  To split Player column and create two new columns : splitting the 'Player' column to get the information about 'Country'

# %%
df_player = df['Player'].str.split("(", expand=True)

display(df_player.head(10))
# Out:
#                  0              1
# 0  M Muralitharan    Asia/ICC/SL)
# 1     Wasim Akram            PAK)
# 2    Waqar Younis            PAK)
# 3      WPUJC Vaas        Asia/SL)
# 4   Shahid Afridi   Asia/ICC/PAK)
# 5      SM Pollock     Afr/ICC/SA)
# 6      GD McGrath        AUS/ICC)
# 7           B Lee            AUS)
# 8      SL Malinga             SL)
# 9        A Kumble     Asia/INDIA)

# %% [markdown]
# ### Adding Player_Name and Country columns in the data set

# %%
df[["Player_Name", "Country"]] = df['Player'].str.split("(", expand=True)

display(df.head())
# Out:
#                          Player       Span  Match  Innings  Balls   Runs  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011    350      341  18811  12326
# 1             Wasim Akram (PAK)  1984-2003    356      351  18186  11812
# 2            Waqar Younis (PAK)  1989-2003    262      258  12698   9919
# 3          WPUJC Vaas (Asia/SL)  1994-2008    322      320  15775  11014
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015    398      372  17670  13632
#
#    Wicket  Average  Economy Rate  Strike_Rate   4   5      Player_Name  \
# 0     534    23.08          3.93         35.2  15  10  M Muralitharan
# 1     502    23.52          3.89         36.2  17   6     Wasim Akram
# 2     416    23.84          4.68         30.5  14  13    Waqar Younis
# 3     400    27.53          4.18         39.4   9   4      WPUJC Vaas
# 4     395    34.51          4.62         44.7   4   9   Shahid Afridi
#
#          Country
# 0   Asia/ICC/SL)
# 1           PAK)
# 2           PAK)
# 3       Asia/SL)
# 4  Asia/ICC/PAK)

# %% [markdown]
# ### Removing Player column

# %%
df = df.drop('Player', axis=1)
display(df.head())
# Out:
#         Span  Match  Innings  Balls   Runs  Wicket  Average  Economy Rate  \
# 0  1993-2011    350      341  18811  12326     534    23.08          3.93
# 1  1984-2003    356      351  18186  11812     502    23.52          3.89
# 2  1989-2003    262      258  12698   9919     416    23.84          4.68
# 3  1994-2008    322      320  15775  11014     400    27.53          4.18
# 4  1996-2015    398      372  17670  13632     395    34.51          4.62
#
#    Strike_Rate   4   5      Player_Name        Country
# 0         35.2  15  10  M Muralitharan    Asia/ICC/SL)
# 1         36.2  17   6     Wasim Akram            PAK)
# 2         30.5  14  13    Waqar Younis            PAK)
# 3         39.4   9   4      WPUJC Vaas        Asia/SL)
# 4         44.7   4   9   Shahid Afridi   Asia/ICC/PAK)

# %% [markdown]
# ### Removing  ) value from Country column

# %%
df['Country'] = df['Country'].str.replace(")", "")

display(df.head())
# Out:
#         Span  Match  Innings  Balls   Runs  Wicket  Average  Economy Rate  \
# 0  1993-2011    350      341  18811  12326     534    23.08          3.93
# 1  1984-2003    356      351  18186  11812     502    23.52          3.89
# 2  1989-2003    262      258  12698   9919     416    23.84          4.68
# 3  1994-2008    322      320  15775  11014     400    27.53          4.18
# 4  1996-2015    398      372  17670  13632     395    34.51          4.62
#
#    Strike_Rate   4   5      Player_Name       Country
# 0         35.2  15  10  M Muralitharan    Asia/ICC/SL
# 1         36.2  17   6     Wasim Akram            PAK
# 2         30.5  14  13    Waqar Younis            PAK
# 3         39.4   9   4      WPUJC Vaas        Asia/SL
# 4         44.7   4   9   Shahid Afridi   Asia/ICC/PAK

# %% [markdown]
# ### Rearranging column names

# %%
new_col_sequence = ['Player_Name', 'Country', 'Span', 'Match', 'Innings', 'Balls', 'Runs', 'Wicket',
       'Average', 'Economy Rate', 'Strike_Rate', 4, 5]
df = df[new_col_sequence]
display(df.head())
# Out:
#        Player_Name       Country       Span  Match  Innings  Balls   Runs  \
# 0  M Muralitharan    Asia/ICC/SL  1993-2011    350      341  18811  12326
# 1     Wasim Akram            PAK  1984-2003    356      351  18186  11812
# 2    Waqar Younis            PAK  1989-2003    262      258  12698   9919
# 3      WPUJC Vaas        Asia/SL  1994-2008    322      320  15775  11014
# 4   Shahid Afridi   Asia/ICC/PAK  1996-2015    398      372  17670  13632
#
#    Wicket  Average  Economy Rate  Strike_Rate   4   5
# 0     534    23.08          3.93         35.2  15  10
# 1     502    23.52          3.89         36.2  17   6
# 2     416    23.84          4.68         30.5  14  13
# 3     400    27.53          4.18         39.4   9   4
# 4     395    34.51          4.62         44.7   4   9

# %% [markdown]
# ### Unique Country list

# %%
df['Country'].unique()
# Out:
# array(['Asia/ICC/SL', 'PAK', 'Asia/SL', 'Asia/ICC/PAK', 'Afr/ICC/SA',
#        'AUS/ICC', 'AUS', 'SL', 'Asia/INDIA', 'INDIA', 'ICC/NZ', 'BAN',
#        'SA', 'Asia/BAN', 'ENG', 'Asia/PAK', 'ICC/SA', 'NZ', 'Afr/ZIM',
#        'ENG/ICC', 'WI', 'Afr/SA', 'ICC/WI', 'AFG'], dtype=object)

# %% [markdown]
# ### Value Counts of Country Column

# %%
df['Country'].value_counts()
# Out:
# INDIA           9
# PAK             9
# AUS             8
# NZ              6
# SL              5
# WI              5
# Asia/INDIA      4
# ENG             4
# Asia/SL         3
# SA              3
# Afr/ICC/SA      2
# AUS/ICC         2
# Asia/ICC/PAK    2
# ENG/ICC         2
# ICC/NZ          2
# BAN             2
# Afr/SA          2
# ICC/WI          1
# Asia/ICC/SL     1
# Afr/ZIM         1
# ICC/SA          1
# Asia/PAK        1
# Asia/BAN        1
# AFG             1
# Name: Country, dtype: int64

# %% [markdown]
# ### Checking where ICC, Asia, Africa have or not

# %%
def icc_check(i):
    if "ICC" in i:
        return "Yes"
    else:
        return "No"
    
def asia_check(x):
    if "Asia" in x:
        return "Yes"
    else:
        return "No"

def africa_check(x):
    if "Afr" in x:
        return "Yes"
    else:
        return "No"
    
df['Played_for_ICC'] = df['Country'].apply(icc_check)
df['Played_for_Asia'] = df['Country'].apply(asia_check)
df['Played_for_Africa'] = df['Country'].apply(africa_check)
display(df.head(10))
# Out:
#        Player_Name       Country       Span  Match  Innings  Balls   Runs  \
# 0  M Muralitharan    Asia/ICC/SL  1993-2011    350      341  18811  12326
# 1     Wasim Akram            PAK  1984-2003    356      351  18186  11812
# 2    Waqar Younis            PAK  1989-2003    262      258  12698   9919
# 3      WPUJC Vaas        Asia/SL  1994-2008    322      320  15775  11014
# 4   Shahid Afridi   Asia/ICC/PAK  1996-2015    398      372  17670  13632
# 5      SM Pollock     Afr/ICC/SA  1996-2008    303      297  15712   9631
# 6      GD McGrath        AUS/ICC  1993-2007    250      248  12970   8391
# 7           B Lee            AUS  2000-2012    221      217  11185   8877
# 8      SL Malinga             SL  2004-2019    226      220  10936   9760
# 9        A Kumble     Asia/INDIA  1990-2007    271      265  14496  10412
#
#    Wicket  Average  Economy Rate  Strike_Rate   4   5 Played_for_ICC  \
# 0     534    23.08          3.93         35.2  15  10            Yes
# 1     502    23.52          3.89         36.2  17   6             No
# 2     416    23.84          4.68         30.5  14  13             No
# 3     400    27.53          4.18         39.4   9   4             No
# 4     395    34.51          4.62         44.7   4   9            Yes
# 5     393    24.50          3.67         39.9  12   5            Yes
# 6     381    22.02          3.88         34.0   9   7            Yes
# 7     380    23.36          4.76         29.4  14   9             No
# 8     338    28.87          5.35         32.3  11   8             No
# 9     337    30.89          4.30         43.0   8   2             No
#
#   Played_for_Asia Played_for_Africa
# 0             Yes                No
# 1              No                No
# 2              No                No
# 3             Yes                No
# 4             Yes                No
# 5              No               Yes
# 6              No                No
# 7              No                No
# 8              No                No
# 9             Yes                No

# %% [markdown]
# ### Finding how many players played for ICC

# %%
print('ICC:',df['Played_for_ICC'].value_counts())
# Out:
# ICC: No     64
# Yes    13
# Name: Played_for_ICC, dtype: int64

# %% [markdown]
# ### Removing ICC/ /ICC Asia/ Afr/ from the 'Country'

# %%
df['Country'] = df['Country'].str.replace("ICC/", "")
df['Country'] = df['Country'].str.replace("/ICC", "")
df['Country'] = df['Country'].str.replace("Asia/", "")
df['Country'] = df['Country'].str.replace("Afr/", "")

display(df.head(10))
# Out:
#        Player_Name Country       Span  Match  Innings  Balls   Runs  Wicket  \
# 0  M Muralitharan       SL  1993-2011    350      341  18811  12326     534
# 1     Wasim Akram      PAK  1984-2003    356      351  18186  11812     502
# 2    Waqar Younis      PAK  1989-2003    262      258  12698   9919     416
# 3      WPUJC Vaas       SL  1994-2008    322      320  15775  11014     400
# 4   Shahid Afridi      PAK  1996-2015    398      372  17670  13632     395
# 5      SM Pollock       SA  1996-2008    303      297  15712   9631     393
# 6      GD McGrath      AUS  1993-2007    250      248  12970   8391     381
# 7           B Lee      AUS  2000-2012    221      217  11185   8877     380
# 8      SL Malinga       SL  2004-2019    226      220  10936   9760     338
# 9        A Kumble    INDIA  1990-2007    271      265  14496  10412     337
#
#    Average  Economy Rate  Strike_Rate   4   5 Played_for_ICC Played_for_Asia  \
# 0    23.08          3.93         35.2  15  10            Yes             Yes
# 1    23.52          3.89         36.2  17   6             No              No
# 2    23.84          4.68         30.5  14  13             No              No
# 3    27.53          4.18         39.4   9   4             No             Yes
# 4    34.51          4.62         44.7   4   9            Yes             Yes
# 5    24.50          3.67         39.9  12   5            Yes              No
# 6    22.02          3.88         34.0   9   7            Yes              No
# 7    23.36          4.76         29.4  14   9             No              No
# 8    28.87          5.35         32.3  11   8             No              No
# 9    30.89          4.30         43.0   8   2             No             Yes
#
#   Played_for_Africa
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# 5               Yes
# 6                No
# 7                No
# 8                No
# 9                No

# %% [markdown]
# ### Checking the unique values for Country column

# %%
df['Country'].value_counts()
# Out:
# INDIA    13
# PAK      12
# AUS      10
# SL        9
# SA        8
# NZ        8
# ENG       6
# WI        6
# BAN       3
# ZIM       1
# AFG       1
# Name: Country, dtype: int64

# %% [markdown]
# #### There are 11 different countries are present in this dataset.

# %% [markdown]
# #### Finding number of years played

# %%
# splitting the 'Span' column based on the "-"
df[['Start_year', 'End_year']] = df['Span'].str.split("-", expand=True)

# removing the "Span" column
df = df.drop("Span", axis=1)

display(df.head())
# Out:
#        Player_Name Country  Match  Innings  Balls   Runs  Wicket  Average  \
# 0  M Muralitharan       SL    350      341  18811  12326     534    23.08
# 1     Wasim Akram      PAK    356      351  18186  11812     502    23.52
# 2    Waqar Younis      PAK    262      258  12698   9919     416    23.84
# 3      WPUJC Vaas       SL    322      320  15775  11014     400    27.53
# 4   Shahid Afridi      PAK    398      372  17670  13632     395    34.51
#
#    Economy Rate  Strike_Rate   4   5 Played_for_ICC Played_for_Asia  \
# 0          3.93         35.2  15  10            Yes             Yes
# 1          3.89         36.2  17   6             No              No
# 2          4.68         30.5  14  13             No              No
# 3          4.18         39.4   9   4             No             Yes
# 4          4.62         44.7   4   9            Yes             Yes
#
#   Played_for_Africa Start_year End_year
# 0                No       1993     2011
# 1                No       1984     2003
# 2                No       1989     2003
# 3                No       1994     2008
# 4                No       1996     2015

# %% [markdown]
# As there are Strat_year and End_year columns so I think Span column is unnecessary. That's why I removed Span column.

# %% [markdown]
# ### Checking data types of Start_year and End_year columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player_Name        77 non-null     object
#  1   Country            77 non-null     object
#  2   Match              77 non-null     int64
#  3   Innings            77 non-null     int64
#  4   Balls              77 non-null     int64
#  5   Runs               77 non-null     int64
#  6   Wicket             77 non-null     int64
#  7   Average            77 non-null     float64
#  8   Economy Rate       77 non-null     float64
#  9   Strike_Rate        77 non-null     float64
#  10  4                  77 non-null     int64
#  11  5                  77 non-null     int64
#  12  Played_for_ICC     77 non-null     object
#  13  Played_for_Asia    77 non-null     object
#  14  Played_for_Africa  77 non-null     object
#  15  Start_year         77 non-null     object
#  16  End_year           77 non-null     object
# dtypes: float64(3), int64(7), object(7)
# memory usage: 10.4+ KB

# %% [markdown]
# **Data type conversion**: Converting Start_year and End_year columns data type from String to integer.

# %%
df['Start_year'] = df['Start_year'].astype('int') 
df['End_year'] = df['End_year'].astype('int')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player_Name        77 non-null     object
#  1   Country            77 non-null     object
#  2   Match              77 non-null     int64
#  3   Innings            77 non-null     int64
#  4   Balls              77 non-null     int64
#  5   Runs               77 non-null     int64
#  6   Wicket             77 non-null     int64
#  7   Average            77 non-null     float64
#  8   Economy Rate       77 non-null     float64
#  9   Strike_Rate        77 non-null     float64
#  10  4                  77 non-null     int64
#  11  5                  77 non-null     int64
#  12  Played_for_ICC     77 non-null     object
#  13  Played_for_Asia    77 non-null     object
#  14  Played_for_Africa  77 non-null     object
#  15  Start_year         77 non-null     int32
#  16  End_year           77 non-null     int32
# dtypes: float64(3), int32(2), int64(7), object(5)
# memory usage: 9.8+ KB
# None

# %% [markdown]
# ### Finding the years played of each player

# %%
df['Years_played'] = df['End_year'] - df['Start_year'] + 1

df = df.drop(['Start_year', "End_year"], axis=1) #Removing Start_year and End_year from data set

display(df.head(10))
# Out:
#        Player_Name Country  Match  Innings  Balls   Runs  Wicket  Average  \
# 0  M Muralitharan       SL    350      341  18811  12326     534    23.08
# 1     Wasim Akram      PAK    356      351  18186  11812     502    23.52
# 2    Waqar Younis      PAK    262      258  12698   9919     416    23.84
# 3      WPUJC Vaas       SL    322      320  15775  11014     400    27.53
# 4   Shahid Afridi      PAK    398      372  17670  13632     395    34.51
# 5      SM Pollock       SA    303      297  15712   9631     393    24.50
# 6      GD McGrath      AUS    250      248  12970   8391     381    22.02
# 7           B Lee      AUS    221      217  11185   8877     380    23.36
# 8      SL Malinga       SL    226      220  10936   9760     338    28.87
# 9        A Kumble    INDIA    271      265  14496  10412     337    30.89
#
#    Economy Rate  Strike_Rate   4   5 Played_for_ICC Played_for_Asia  \
# 0          3.93         35.2  15  10            Yes             Yes
# 1          3.89         36.2  17   6             No              No
# 2          4.68         30.5  14  13             No              No
# 3          4.18         39.4   9   4             No             Yes
# 4          4.62         44.7   4   9            Yes             Yes
# 5          3.67         39.9  12   5            Yes              No
# 6          3.88         34.0   9   7            Yes              No
# 7          4.76         29.4  14   9             No              No
# 8          5.35         32.3  11   8             No              No
# 9          4.30         43.0   8   2             No             Yes
#
#   Played_for_Africa  Years_played
# 0                No            19
# 1                No            20
# 2                No            15
# 3                No            15
# 4                No            20
# 5               Yes            13
# 6                No            15
# 7                No            13
# 8                No            16
# 9                No            18

# %% [markdown]
# ### Players had played for the longest period of time

# %%
df.sort_values(by='Years_played', ascending = False).head(5)
# Out:
#        Player_Name Country  Match  Innings  Balls   Runs  Wicket  Average  \
# 72   SR Tendulkar    INDIA    463      270   8054   6850     154    44.48
# 10  ST Jayasuriya       SL    445      368  14874  11871     323    36.75
# 66   Shoaib Malik      PAK    287      217   7958   6192     158    39.18
# 62       CH Gayle       WI    301      199   7424   5926     167    35.48
# 4   Shahid Afridi      PAK    398      372  17670  13632     395    34.51
#
#     Economy Rate  Strike_Rate  4  5 Played_for_ICC Played_for_Asia  \
# 72          5.10         52.2  4  2             No              No
# 10          4.78         46.0  8  4             No             Yes
# 66          4.66         50.3  1  0             No              No
# 62          4.78         44.4  3  1            Yes              No
# 4           4.62         44.7  4  9            Yes             Yes
#
#    Played_for_Africa  Years_played
# 72                No            24
# 10                No            23
# 66                No            21
# 62                No            21
# 4                 No            20

# %% [markdown]
# SR Tendulkar had played for the longest period of time.

# %% [markdown]
# ### Players had played for the shortest period of time

# %%
df.sort_values(by='Years_played').head(5)
# Out:
#      Player_Name Country  Match  Innings  Balls  Runs  Wicket  Average  \
# 40   BKV Prasad    INDIA    161      160   8129  6332     196    32.30
# 74  Rashid Khan      AFG     80       76   4074  2821     151    18.68
# 73   BAW Mendis       SL     87       84   4154  3324     152    21.86
# 49  Saeed Ajmal      PAK    113      112   6000  4182     184    22.72
# 44   L Klusener       SA    171      164   7336  5751     192    29.95
#
#     Economy Rate  Strike_Rate  4  5 Played_for_ICC Played_for_Asia  \
# 40          4.67         41.4  3  1             No              No
# 74          4.15         26.9  5  4             No              No
# 73          4.80         27.3  7  3             No              No
# 49          4.18         32.6  6  2             No              No
# 44          4.70         38.2  1  6             No              No
#
#    Played_for_Africa  Years_played
# 40                No             8
# 74                No             8
# 73                No             8
# 49                No             8
# 44                No             9

# %% [markdown]
# BKV Prasad,Rashid Khan,BAW Mendis,Saeed Ajmal had played for the shortest period of time.

# %% [markdown]
# ### Australian Bowlers list in this dataset

# %%
filter_condition=df['Country']=='AUS'
df[filter_condition]
# Out:
#       Player_Name Country  Match  Innings  Balls  Runs  Wicket  Average  \
# 6     GD McGrath      AUS    250      248  12970  8391     381    22.02
# 7          B Lee      AUS    221      217  11185  8877     380    23.36
# 13      SK Warne      AUS    194      191  10642  7541     293    25.73
# 28    MG Johnson      AUS    153      150   7489  6038     239    25.26
# 34  CJ McDermott      AUS    138      138   7461  5018     203    24.71
# 41      MA Starc      AUS     99       99   5099  4379     195    22.45
# 42      SR Waugh      AUS    325      207   8883  6761     195    34.67
# 55    NW Bracken      AUS    116      116   5759  4240     174    24.36
# 61     SR Watson      AUS    190      163   6466  5342     168    31.79
# 70       GB Hogg      AUS    123      113   5564  4188     156    26.84
#
#     Economy Rate  Strike_Rate   4  5 Played_for_ICC Played_for_Asia  \
# 6           3.88         34.0   9  7            Yes              No
# 7           4.76         29.4  14  9             No              No
# 13          4.25         36.3  12  1            Yes              No
# 28          4.83         31.3   9  3             No              No
# 34          4.03         36.7   4  1             No              No
# 41          5.15         26.1  11  8             No              No
# 42          4.56         45.5   3  0             No              No
# 55          4.41         33.0   5  2             No              No
# 61          4.95         38.4   3  0             No              No
# 70          4.51         35.6   3  2             No              No
#
#    Played_for_Africa  Years_played
# 6                 No            15
# 7                 No            13
# 13                No            13
# 28                No            11
# 34                No            12
# 41                No            12
# 42                No            17
# 55                No             9
# 61                No            14
# 70                No            13

# %% [markdown]
# There are 10 Australian Bowlers are present in this dataset.

# %% [markdown]
# ### Checking Bangladeshi player present in this dataset

# %%
filter_condition=df['Country']=='BAN'
df[filter_condition]
# Out:
#           Player_Name Country  Match  Innings  Balls  Runs  Wicket  Average  \
# 16   Shakib Al Hasan      BAN    221      218  11351  8401     285    29.47
# 20  Mashrafe Mortaza      BAN    220      220  10922  8893     270    32.93
# 33      Abdur Razzak      BAN    153      152   7965  6065     207    29.29
#
#     Economy Rate  Strike_Rate  4  5 Played_for_ICC Played_for_Asia  \
# 16          4.44         39.8  9  3             No              No
# 20          4.88         40.4  7  1             No             Yes
# 33          4.56         38.4  5  4             No              No
#
#    Played_for_Africa  Years_played
# 16                No            17
# 20                No            20
# 33                No            11

# %% [markdown]
# There are 3 Bangladeshi players present in this dataset.

# %% [markdown]
# ### Players had the lowest economy rate

# %%
df.sort_values(by='Economy Rate').head(5)
# Out:
#      Player_Name Country  Match  Innings  Balls  Runs  Wicket  Average  \
# 65    RJ Hadlee       NZ    115      112   6182  3407     158    21.56
# 32  CEL Ambrose       WI    176      175   9353  5429     225    24.12
# 67  MD Marshall       WI    136      134   7175  4233     157    26.96
# 5    SM Pollock       SA    303      297  15712  9631     393    24.50
# 25  N Kapil Dev    INDIA    225      221  11202  6945     253    27.45
#
#     Economy Rate  Strike_Rate   4  5 Played_for_ICC Played_for_Asia  \
# 65          3.30         39.1   1  5             No              No
# 32          3.48         41.5   6  4             No              No
# 67          3.53         45.7   6  0             No              No
# 5           3.67         39.9  12  5            Yes              No
# 25          3.71         44.2   3  1             No              No
#
#    Played_for_Africa  Years_played
# 65                No            18
# 32                No            13
# 67                No            13
# 5                Yes            13
# 25                No            17

# %% [markdown]
# RJ Hadlee had the lowest economy rate.

# %% [markdown]
# ### Players had the lowest strike rate

# %%
df.sort_values(by='Strike_Rate').head(5)
# Out:
#      Player_Name Country  Match  Innings  Balls  Runs  Wicket  Average  \
# 41     MA Starc      AUS     99       99   5099  4379     195    22.45
# 74  Rashid Khan      AFG     80       76   4074  2821     151    18.68
# 73   BAW Mendis       SL     87       84   4154  3324     152    21.86
# 7         B Lee      AUS    221      217  11185  8877     380    23.36
# 60     TA Boult       NZ     93       93   5117  4261     169    25.21
#
#     Economy Rate  Strike_Rate   4  5 Played_for_ICC Played_for_Asia  \
# 41          5.15         26.1  11  8             No              No
# 74          4.15         26.9   5  4             No              No
# 73          4.80         27.3   7  3             No              No
# 7           4.76         29.4  14  9             No              No
# 60          4.99         30.2   8  5             No              No
#
#    Played_for_Africa  Years_played
# 41                No            12
# 74                No             8
# 73                No             8
# 7                 No            13
# 60                No            10

# %% [markdown]
# MA Starc had the lowest strike rate.

# %% [markdown]
# ### Players had the lowest bowling average

# %%
df.sort_values(by='Average').head(5)
# Out:
#          Player_Name Country  Match  Innings  Balls  Runs  Wicket  Average  \
# 74      Rashid Khan      AFG     80       76   4074  2821     151    18.68
# 65        RJ Hadlee       NZ    115      112   6182  3407     158    21.56
# 19        AA Donald       SA    164      162   8561  5926     272    21.78
# 14  Saqlain Mushtaq      PAK    169      165   8770  6275     288    21.78
# 73       BAW Mendis       SL     87       84   4154  3324     152    21.86
#
#     Economy Rate  Strike_Rate   4  5 Played_for_ICC Played_for_Asia  \
# 74          4.15         26.9   5  4             No              No
# 65          3.30         39.1   1  5             No              No
# 19          4.15         31.4  11  2             No              No
# 14          4.29         30.4  11  6             No              No
# 73          4.80         27.3   7  3             No              No
#
#    Played_for_Africa  Years_played
# 74                No             8
# 65                No            18
# 19                No            13
# 14                No             9
# 73                No             8

# %% [markdown]
# Rashid Khan had the lowest bowling average.
